# %% [raw]
# ##write
# ##read
# ##append
# ##readline
# ##readlines

# %% [raw]
# ## write concept

# %%
a=open('C:/Users/vishwateja/Desktop/teja.txt','w')
a.write('i am a python developer')
a.close()

# %% [raw]
# ## read concept

# %%
a=open('C:/Users/vishwateja/Desktop/teja.txt','r')
print(a.read())
a.close()
# Out:
# i am a python developer

# %% [raw]
# ## append(add) concept

# %%
a=open('C:/Users/vishwateja/Desktop/teja.txt','a')
a.write('and also java developer')
a.close()

# %%
a = """A frame is a type of digital data transmission unit utilized in networking and telecommunications. A frame is a straightforward container for a single network packet in packet-switching systems. A frame is a repetitive structure in other telecommunications that allows for time-division multiplexing.

Frame synchronization is a component of most frames, and it is made up of a series of bits or symbols that signal the beginning and end of the payload data inside the stream of symbols or bits received by the receiver. When a frame is transmitted, a receiver connected to the system ignores the information until it notices a fresh frame synchronization sequence."""

# %%
a
# Out:
# 'A frame is a type of digital data transmission unit utilized in networking and telecommunications. A frame is a straightforward container for a single network packet in packet-switching systems. A frame is a repetitive structure in other telecommunications that allows for time-division multiplexing.\n\nFrame synchronization is a component of most frames, and it is made up of a series of bits or symbols that signal the beginning and end of the payload data inside the stream of symbols or bits received by the receiver. When a frame is transmitted, a receiver connected to the system ignores the information until it notices a fresh frame synchronization sequence.'

# %%
k = open('C:/Users/vishwateja/Desktop/teja.txt','w')
k.write(a)
k.close()

# %%
a=open('C:/Users/vishwateja/Desktop/teja.txt','r')
print(a.read())
a.close()
# Out:
# A frame is a type of digital data transmission unit utilized in networking and telecommunications. A frame is a straightforward container for a single network packet in packet-switching systems. A frame is a repetitive structure in other telecommunications that allows for time-division multiplexing.
#
# Frame synchronization is a component of most frames, and it is made up of a series of bits or symbols that signal the beginning and end of the payload data inside the stream of symbols or bits received by the receiver. When a frame is transmitted, a receiver connected to the system ignores the information until it notices a fresh frame synchronization sequence.

# %% [raw]
# ## readline concept

# %%
a=open('C:/Users/vishwateja/Desktop/teja.txt','r')
print(a.readline())
a.close()
# Out:
# A frame is a type of digital data transmission unit utilized in networking and telecommunications. A frame is a straightforward container for a single network packet in packet-switching systems. A frame is a repetitive structure in other telecommunications that allows for time-division multiplexing.

# %% [raw]
# ## readlines concept

# %%
a=open('C:/Users/vishwateja/Desktop/teja.txt','r')
print(a.readlines())
a.close()
# Out:
# ['A frame is a type of digital data transmission unit utilized in networking and telecommunications. A frame is a straightforward container for a single network packet in packet-switching systems. A frame is a repetitive structure in other telecommunications that allows for time-division multiplexing.\n', '\n', 'Frame synchronization is a component of most frames, and it is made up of a series of bits or symbols that signal the beginning and end of the payload data inside the stream of symbols or bits received by the receiver. When a frame is transmitted, a receiver connected to the system ignores the information until it notices a fresh frame synchronization sequence.']

# %% [raw]
# ## with concept

# %%
with open('C:/Users/vishwateja/Desktop/teja.txt','w') as f:
    f.write('python')
    f.close()
