# %% [raw]
# ## FUNCTION KEYWORD-def

# %%
def kamal():
    print("hello")

# %%
kamal()
# Out:
# hello

# %%
def teja():
    print("python")

# %%
teja()
# Out:
# python

# %%
def teja():
    print("pyhton")
    print()
    print("data science")
    print()
    print("machine learning")

# %%
teja()
# Out:
# pyhton
#
# data science
#
# machine learning

# %% [markdown]
# ## without functions

# %%
a=13
if a%2==0:
    print('even')
else:
    print('odd')
# Out:
# odd

# %%
a=22
if a%2==0:
    print('even')
else:
    print('odd')
# Out:
# even

# %% [markdown]
# ## With function

# %%
def virat(i):
    if i%2==0:
        print('even')
        
    else:
        print('odd')

# %%
virat(18)
# Out:
# even

# %% [raw]
# virat(23)

# %%
virat(34)
# Out:
# even

# %% [markdown]
# ## Return concept in functions

# %%
a=int(input())

# %%
c = []
