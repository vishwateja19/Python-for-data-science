# %%
mystring='python'
print(mystring)
# Out:
# python

# %%
print(type(mystring))
# Out:
# <class 'str'>

# %%
k='teja'
print(k[0])
# Out:
# t

# %%
print(k[3])
# Out:
# a

# %%
python='datascience'
print(python[4])
# Out:
# s

# %% [raw]
# ## negative index

# %%
print(python[-3])
# Out:
# n

# %%
print(python[-5])
# Out:
# i

# %% [raw]
# ## Python string slicing

# %%
python='datascience'

# %%
print(python[3:4])
# Out:
# a

# %%
python='datascience'
print(python[3:4])
# Out:
# a

# %%
print(python[-4:-3])
# Out:
# e

# %%
a='datascience'

# %%
#from 3rd character till 9th character
print(a[2:5])
# Out:
# tas

# %%
#python string slicing
python='vishwa'
print(python[1:2])
# Out:
# i

# %%
print(python[0:3])
# Out:
# vis

# %%
t='science'
a
# Out:
# 'datascience'

# %%
t='science'

# %%
t='science'
t
# Out:
# 'science'

# %%
print(type(t))
# Out:
# <class 'str'>

# %%
len(t)
# Out:
# 7

# %%
t[4]
# Out:
# 'n'

# %% [markdown]
# ## slicing operations

# %%
c='artificial intelligence'

# %%
len(c)
# Out:
# 23

# %%
print(c[5:8])
# Out:
# ici

# %%
c[6:10]
# Out:
# 'cial'

# %%
d=c.split()
d
# Out:
# ['artificial', 'intelligence']

# %%
a='vishwateja'

# %%
len(a)
# Out:
# 10

# %%
a.index('w')
# Out:
# 4

# %%
# capitalize
a='vishwateja'
a.capitalize()
# Out:
# 'Vishwateja'

# %%
a.capitalize()
# Out:
# 'Vishwateja'

# %%
## count

a.count('t')
# Out:
# 1

# %%
a.count('a')
# Out:
# 2

# %%
## endswith

a.endswith('a')
# Out:
# True

# %%
a.endswith('t')
# Out:
# False

# %%
a.startswith('v')
# Out:
# True

# %%
## Index

a.index('j')
# Out:
# 8

# %%
## isalpha

a.isalpha()
# Out:
# True

# %%
a.isalnum()
# Out:
# True

# %%
a.isdecimal()
# Out:
# False

# %%
a.islower()
# Out:
# True

# %%
a.lower()
# Out:
# 'vishwateja'

# %%
a.upper()
# Out:
# 'VISHWATEJA'

# %%
## Replace

a.replace('w','l')
# Out:
# 'vishlateja'

# %%
## length

len(a)
# Out:
# 10

# %% [raw]
# ## SPLIT

# %%
a='python is a language'

a.split()
# Out:
# ['python', 'is', 'a', 'language']

# %%
''.join(a)
# Out:
# 'python is a language'

# %%
b= 'india is my country'
b.split()
# Out:
# ['india', 'is', 'my', 'country']

# %%
''.join(b)
# Out:
# 'india is my country'

# %%
a='strings practice'

# %%
len(a)
# Out:
# 16

# %%
a[4:12]
# Out:
# 'ngs prac'

# %%
a[12:14]
# Out:
# 'ti'

# %%
## Membership

t='teja is a ds'
'ds' in t
# Out:
# True

# %%
'teja'in t
# Out:
# True

# %%
a='i am going to school'

a.split()
# Out:
# ['i', 'am', 'going', 'to', 'school']

# %%
''.join(a)
# Out:
# 'i am going to school'

# %%
## skipping concept

a='12345678'

a[:]
# Out:
# '12345678'

# %%
a[::-1]
# Out:
# '87654321'

# %%
a='bandivishwateja'

a[::-1]
# Out:
# 'ajetawhsividnab'

# %%
a[::2]
# Out:
# 'bniihaea'

# %%
a[:]
# Out:
# 'bandivishwateja'

# %%
a[::2]
# Out:
# 'bniihaea'

# %%
a[::3]
# Out:
# 'bdiwe'

# %%
mystring='data science'
print(mystring)
# Out:
# data science

# %%
print(mystring[1:4])
# Out:
# ata

# %%
print(mystring[::1])
# Out:
# data science

# %%
print(mystring[-3:-4])
print(mystring[2:3])
print(mystring[::4])
print(mystring[:])
# Out:
# t
# d e
# data science

# %%
a='python language'
a[:]
# Out:
# 'python language'

# %%
a[::3]
# Out:
# 'ph na'

# %%
a[4:9]
# Out:
# 'on la'

# %%
a[7:12]
# Out:
# 'langu'

# %%
a[8:12]
# Out:
# 'angu'

# %%
a[2:6]
# Out:
# 'thon'

# %%
a='datascience'
a[:-3]
# Out:
# 'datascie'

# %%
a=[1,2,3,4]
print(a)
a[2]=6
print(a)
# Out:
# [1, 2, 3, 4]
# [1, 2, 6, 4]

# %%
b=[12,23,34,55]
print(b)
b[2]=45
print(b)
# Out:
# [12, 23, 34, 55]
# [12, 23, 45, 55]

# %%
a='datascience'
a='python'
print(a)
# Out:
# python

# %%
a='data'
b='python'
print("the value of string1 is "+""+ a +" the value of string2 is "+b)
# Out:
# the value of string1 is data the value of string2 is python

# %%
b='teja'
c='vishwa'
print("the value of string1 is "+""+b +"the value of string2 is"+c)
# Out:
# the value of string1 is tejathe value of string2 isvishwa

# %%
a='prabhas'
b='ntr'
print("the value of string1 is "+""+a +" the value of string2 is "+b)
# Out:
# the value of string1 is prabhas the value of string2 is ntr

# %%
 a='a' * 3
 a
# Out:
# 'aaa'

# %%
string1='data'
string2=string1 * 4
print(string2)
# Out:
# datadatadatadata

# %%
string='i am data scientist'
print('i am' in string)
print('data' in string)
print('science' in string)
print('python' in string)
# Out:
# True
# True
# False
# False

# %%
a='i am teja'
print(a.split(' '))
# Out:
# ['i', 'am', 'teja']

# %%
print(a.join(' '))
print(a)
# Out:
#
# i am teja

# %%
b='python is a pragraming language'
print(b.split(' '))
print(b.join(' '))
print(b)
# Out:
# ['python', 'is', 'a', 'pragraming', 'language']
#
# python is a pragraming language

# %%
b='python is a pragraming language'
print(b.split(' '))
print(' '.join(b))
print(b)
# Out:
# ['python', 'is', 'a', 'pragraming', 'language']
# p y t h o n   i s   a   p r a g r a m i n g   l a n g u a g e
# python is a pragraming language

# %%
b='python is a pragraming language'
print(len(b))
# Out:
# 31

# %%
b='python is a pragraming language'
b.capitalize()
# Out:
# 'Python is a pragraming language'

# %%
b='Python is a pragraming language'
b.lower()
# Out:
# 'python is a pragraming language'

# %%
b='Python is a pragraming language'
b.count('a')
# Out:
# 5

# %%
b='Python is a pragraming language'
b.count('is a')
# Out:
# 1

# %%
b='python is a pragraming language'
b.upper()
# Out:
# 'PYTHON IS A PRAGRAMING LANGUAGE'

# %%
b='python is a pragraming language'
print(b.index("prag"))
# Out:
# 12

# %%
a='virat kohli goat of cricket'
print(a.index('kohli'))
# Out:
# 6

# %%
a='virat kohli goat of cricket'
a.replace('goat','great')
# Out:
# 'virat kohli great of cricket'

# %%
c='data is powerful in itself'
c.replace('powerful','best')
# Out:
# 'data is best in itself'

# %%
print(c.isalpha())
# Out:
# True

# %%
c='data is powerful in itself'
c.isdigit()
# Out:
# False

# %%
print('i am {} '.format("teja"))
print('im the best person in the {}'.format("world"))
# Out:
# i am teja
# im the best person in the world

# %%
print('cricketers are {a},{b},{c}'.format(a='virat',b='dhoni',c='rohit'))
# Out:
# cricketers are virat,dhoni,rohit
