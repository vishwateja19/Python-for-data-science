# %% [raw]
# ## List is represented by[ ]

# %%
a=[1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
len(a)
# Out:
# 5

# %%
a[2]
# Out:
# 3

# %%
# Out:
# [2, 4, 'teja']

# %%
type(a)
# Out:
# list

# %%
str(a)
# Out:
# "[2, 4, 'teja']"

# %%
a=[2,4,'teja']
del a[1]
a
# Out:
# [2, 'teja']

# %% [raw]
# ## predefined methods

# %%
a=[2,3,2.5,'data']
print(type(a))
len(a)
# Out:
# <class 'list'>
# 4

# %%
a.append('king') ## append function
a
# Out:
# [2, 3, 2.5, 'data', 'king']

# %%
## clear function

a.clear()
a
# Out:
# []

# %%
a=[2,4,'teja']
a
a.count('teja')
a
# Out:
# [2, 4, 'teja']

# %%
a.count('teja')
# Out:
# 1

# %%
## copy function

b=a.copy()
a
# Out:
# [2, 4, 'teja']

# %%
a
# Out:
# [2, 4, 'teja']

# %%
## Extend function
a=[2,4,'teja']
a
# Out:
# [2, 4, 'teja']

# %%
b=[5,6]

a.extend(b)
a
# Out:
# [2, 4, 'teja', 5, 6, 5, 6]

# %%
## Index function

# %%
a=[2,4,'teja']

a.index(4)
# Out:
# 1

# %%
a.index('teja')
# Out:
# 2

# %%
## Insert function

# %%
a=[2,4,'teja']

a.insert(1,5)
a
# Out:
# [2, 5, 4, 'teja']

# %%
a.insert(0,23)
a
# Out:
# [23, 2, 5, 4, 'teja']

# %%
## pop function

a.pop()
a
# Out:
# [23, 2, 5, 4]

# %%
a.pop()
a
# Out:
# [23, 2, 5]

# %%
## remove function

# %%
a=[2,4,'teja']

a.remove('teja')
a
# Out:
# [2, 4]

# %%
a[::-1]
# Out:
# [4, 2]

# %%
## Reverse
a.reverse()
a
# Out:
# [4, 2]

# %%
## Sort function
    
a.sort()    
a
# Out:
# [2, 4]
