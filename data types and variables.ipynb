# %% [markdown]
# ## practice data types

# %%
a=13
print(a)
# Out:
# 13

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
teja='parsy'
print(teja)
# Out:
# parsy

# %%
print(type(teja))
# Out:
# <class 'str'>

# %%
_teja='mom'
print(_teja)
# Out:
# mom

# %%
vishwatejabandi=22
print(vishwatejabandi)
# Out:
# 22

# %%
vishwa_teja_bandi=23
print(vishwa_teja_bandi)
# Out:
# 23

# %% [raw]
# #cannot use special characters as variables

# %% [markdown]
# CONVERSIONS

# %% [raw]
# # int to float

# %%
a=23
print(a)
print(type(a))
b=float(a)
print(b)
print(type(b))
# Out:
# 23
# <class 'int'>
# 23.0
# <class 'float'>

# %%
a=44
print(a)
print(type(a))
b=float(a)
print(b)
print(type(b))
# Out:
# 44
# <class 'int'>
# 44.0
# <class 'float'>

# %% [raw]
# ## float to int

# %%
a=99.34
print(a)
print(type(a))
b=int(a)
print(b)
print(type(b))
# Out:
# 99.34
# <class 'float'>
# 99
# <class 'int'>

# %% [markdown]
# ## converting int and float to string

# %%
a=22
print(a)
print(type(a))
b=str(a)
print(b)
print(type(b))
# Out:
# 22
# <class 'int'>
# 22
# <class 'str'>

# %%
f=12
str(f)
# Out:
# '12'

# %% [markdown]
# ## converting str to int

# %%
a='2754'
print(a)
print(type(a))
b=int(a)
print(b)
print(type(b))
# Out:
# 2754
# <class 'str'>
# 2754
# <class 'int'>

# %%
a='12.24'
print(a)
print(type(a))

b=float(a)
print(b)
print(type(b))
# Out:
# 12.24
# <class 'str'>
# 12.24
# <class 'float'>

# %%
a='123'
print(a)
print(type(a))
b=int(a)
print(b)
print(type(b))
# Out:
# 123
# <class 'str'>
# 123
# <class 'int'>

# %%
a='123'
print(a)
print(type(a))
b=int(a)
print(b)
print(type(b))
# Out:
# 123
# <class 'str'>
# 123
# <class 'int'>

# %% [markdown]
# ## Rules to add variable and print condition

# %%
a=23
print('my name is teja and my age is' ,a)
# Out:
# my name is teja and my age is 23

# %%
a=23
b=teja
c=35.0

print('my name is' ,b, 'and my age is' ,a,'and my room number' ,c)
# Out:
# my name is parsy and my age is 23 and my room number 35.0

# %%
a='teja'
b='eturunagaram'
c='warangal'

print('my name is',a,'and i am from',b,' i live in',c)
# Out:
# my name is teja and i am from eturunagaram  i live in warangal

# %%
a='python'
b='machine learning'
c='deep learning'

print('by using',a,'we can learn',b,'and',c)
# Out:
# by using python we can learn machine learning and deep learning

# %%
a='teja'
b=1999
c='hyderabad'


print('my name is',a,'i was born on',b,'in',c)
# Out:
# my name is teja i was born on 1999 in hyderabad

# %% [markdown]
# ## rule no 2 using(+)

# %%
a=23
b=teja
c=40.0

print('my name is'+b+'and my age is'+str(a)+'and my currency is' +str(c))
# Out:
# my name isparsyand my age is23and my currency is40.0

# %%
a='teja'
b=23
c=1999


print('my name is'+a+'and my age is'+str(b)+'and the year i was born was'+str(c))
# Out:
# my name istejaand my age is23and the year i was born was1999

# %%
A='python'
B='machine learning'
C='deep learning'


print('using'+''+A+''+'we can learn'+''+B+''+'and'+''+C)
# Out:
# usingpythonwe can learnmachine learninganddeep learning

# %% [markdown]
# ## Rule 3 using %

# %%
# int(%d)
#float(%f)
#string(%s)

# %%
a=25

print('%d is my age'%a)
# Out:
# 25 is my age

# %%
a=23
b=40.0

print('my age is %d and my currency is %f'%(a,b))
# Out:
# my age is 23 and my currency is 40.000000

# %%
a=23
b='vishwa'

print('my name is %s and my age is %d'%(b,a))
# Out:
# my name is vishwa and my age is 23

# %% [raw]
# #Format tecnique

# %%
a=23
b='teja'

print('my name is {} and my age is {}'.format(b,a))
# Out:
# my name is teja and my age is 23

# %%
a='uma'
b=40


print('my mother name is {} and her age is {}'.format(a,b))
# Out:
# my mother name is uma and her age is 40

# %%
a='uma'
b='srinivas'

print('my moms name is {} and my fathers name is {}'.format(a,b))
# Out:
# my moms name is uma and my fathers name is srinivas

# %% [markdown]
# # F symbol

# %%
a=23

print(f'my age is {a}')
# Out:
# my age is 23

# %%
a='teja'


print(f'my name is {a}')
# Out:
# my name is teja

# %%
a='teja234'
print(a)
print(type(a))
print()
b=int
print(b)
print(type(b))
# Out:
# teja234
# <class 'str'>
#
# <class 'int'>
# <class 'type'>

# %%
a='teja'
b=23
c='eturunagaram'

print('my name is',a,'and my age is',b,'and my place is',c,)
# Out:
# my name is teja and my age is 23 and my place is eturunagaram

# %%
a=23

print('my name is vishwa and my age is'+str(a))
# Out:
# my name is vishwa and my age is23

# %%
a=23
b='vishwa'
c=35


print('my name is'+b+'and my age is'+str(a)+'and my currency is'+str(c))
# Out:
# my name isvishwaand my age is23and my currency is35

# %%
a=23
b='vishwa'
c=40.0

print("my name is"+' '+b+' '+'and my age is'+' '+str(c))
# Out:
# my name is vishwa and my age is 40.0

# %%
a='python'
b='deep learning'
c='machine learning'


print('using'+' '+a+' '+'we can learn'+' '+b+' '+'and'+' ' +c)
# Out:
# using python we can learn deep learning and machine learning

# %%
a=12
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
a='data'
print(a)
print(type(a))
# Out:
# data
# <class 'str'>

# %%
b=12.22
print(b)
print(type(b))
# Out:
# 12.22
# <class 'float'>

# %%
b=12
c=str(b)
print(c)
print(type(c))
# Out:
# 12
# <class 'str'>

# %%
a=12.6
b=int(a)
print(b)
print(type(b))
# Out:
# 12
# <class 'int'>

# %%
a = 98.9
print(a)
print(type(a))
print()
b = int(a)
print(b)
print(type(b))
# Out:
# 98.9
# <class 'float'>
#
# 98
# <class 'int'>

# %%
a=10.2
print(a)
print(type(a))
b=int(a)
print(b)
print(type(b))
# Out:
# 10.2
# <class 'float'>
# 10
# <class 'int'>

# %%
a='12.4'
b=float(a)
print(b)
c=int(b)
print(c)
print(type(c))
# Out:
# 12.4
# 12
# <class 'int'>

# %%
a=23
print('vishwa is age is',a)
# Out:
# vishwa is age is 23

# %%
b=18
print('virat jersy is',b)
# Out:
# virat jersy is 18

# %%
a=18
b=7
c=45
print('virat jersy is',a,'dhoni jersy is',b,'rohit jersy is',c)
# Out:
# virat jersy is 18 dhoni jersy is 7 rohit jersy is 45

# %%
b=23
print('my age is'+str(b))
# Out:
# my age is23

# %%
a=23
b='teja'
c=40.0
print('my name is ' +b+' and my age is '+str(a)+'and my currency is '+str(c))
# Out:
# my name is teja and my age is 23and my currency is 40.0

# %%
a=1999
print('my birth date is {}'.format(a))
# Out:
# my birth date is 1999

# %%
a=7
print('ronaldo jersy number is {}'.format(a))
# Out:
# ronaldo jersy number is 7

# %%
a=23
print(f'my age is {a}')
# Out:
# my age is 23

# %%
a=18
b=45
print(f'virat is {a} and rohit is {b}')
# Out:
# virat is 18 and rohit is 45
